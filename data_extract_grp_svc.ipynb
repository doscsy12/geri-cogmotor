# %% [markdown]
# ## ARISE-GERI data analysis

# %% [markdown]
# *import libraries*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime 
import os
import glob
from scipy import interpolate
import statistics

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.options.display.max_rows = 500

# %% [markdown]
# ### Data

# %%
patient_nr = 'P12'
path = './data/ARISE_GERI/' + patient_nr

# %% [markdown]
# **H-MAN sensor data (FILE_ID.dat)**

# %%
# loop dfs from *.dat for defined patient_nr
list_of_dfs = []

list_of_dfs = [pd.read_csv(filename, sep='\t+', header=[1]) for filename in glob.glob(path + '/*.dat')]

# %%
# sample of one df
list_of_dfs[0]
# Out:
#         Time_msec  RawDataX  RawDataY  RawDataTorqueLeft  RawDataTorqueRight
# 0               0  0.170601  0.059062                  0                   0
# 1               5  0.170601  0.059062                  0                   0
# 2              10  0.170601  0.059062                  0                   0
# 3              15  0.170601  0.059062                  0                   0
# 4              20  0.170601  0.059062                  0                   0
# ...           ...       ...       ...                ...                 ...
# 565219    2814785  0.263215  0.213402                  0                   0
# 565220    2814790  0.263115  0.213452                  0                   0
# 565221    2814795  0.263039  0.213477                  0                   0
# 565222    2814800  0.262964  0.213553                  0                   0
# 565223    2814805  0.262863  0.213603                  0                   0
#
# [565224 rows x 5 columns]

# %%
# change column names to lowercase
for df in list_of_dfs:
    df.columns = df.columns.str.lower()

# %% [markdown]
# **Time-stamped data (FILE_ID.tsd)**

# %%
# loop tsds from *.tsd for each patient
list_of_tsds = []

list_of_tsds = [pd.read_csv(filename, sep='\t+', header=[1]) for filename in glob.glob(path + '/*.tsd')]

# %%
list_of_tsds[0]
# Out:
#         t            event_type      Obstacles/Outcome
# 0       289  service_event_start                     0
# 1       639            retrieval                     0
# 2       639            collision                     1
# 3       680            collision                     1
# 4       712         outcome_type                     1
# ..      ...                  ...                   ...
# 591  279874            retrieval                     0
# 592  280716            collision                     1
# 593  281218         outcome_type                     1
# 594  281721    service_event_end                     1
# 595  282224  service_event_start                     0
#
# [596 rows x 3 columns]

# %%
# standardize columns names
for tsd in list_of_tsds:
    tsd.columns = tsd.columns.str.replace(' ','')
    tsd.columns = tsd.columns.str.replace('/','_')
    tsd.columns = tsd.columns.str.lower()

# %% [markdown]
# **Game parameters (FILE_ID.par)**

# %%
list_of_pars = []

list_of_pars = [pd.read_csv(filename, header=[1]) for filename in glob.glob(path + '/*.par')]

# %%
# converting to one column 
list_of_pars[0]
# Out:
#                 CustomerCount:  12
# 0              SessionTimeout:  60
# 1                 FadeOutTime:  15
# 2          CustomerArrivalTime:  4
# 3                  TotalBlocks:  7
# 4               CognitiveLevel:  2
# 5                 HapticsLevel:  2
# 6    Damping Matrix A: 100 200 0 0
# 7        Damping Matrix B: 0 0 0 0
# 8  Damping Matrix C: -30 -30 20 20

# %% [markdown]
# **Researcher reports (FILE_ID.rep)**

# %%
list_of_reps = []

for filename in glob.glob(path + '/*.rep'):
    rep = pd.read_csv(filename, header=[0])
    rep.set_axis(['patientid'], axis=1, inplace=True)
    rep = rep['patientid'].str.split(' ', n=1, expand=True)
    rep = rep.rename(columns={0 : 'parameter', 1 : 'value'})
    rep['value'] = rep['value'].str.replace(' ','')
    list_of_reps.append(rep)

# %%
list_of_reps[0]
# Out:
#                         parameter          value
# 0                         Patient  ID:p12_assess
# 1     SessionTerminationCondition      Completed
# 2                 SessionDuration          19.36
# 3              sumofOutcomesType1             82
# 4              sumofOutcomesType2              2
# 5              sumofOutcomesType3             10
# 6            TotalCustomersServed             84
# 7             AverageReactionTime       10.13103
# 8                    AverageSpeed              0
# 9                   CollisionRate              2
# 10  CumulativePointScoreCognitive            332
# 11      CumulativePointScoreMotor             80

# %% [markdown]
# **quality timestamp check**

# %%
for index in range(0,len(list_of_tsds)):
    diff = abs(list_of_tsds[index]['t'].iloc[-1]  - list_of_dfs[index]['time_msec'].iloc[-1]) 
    if diff > 15:
        print(f'trial{index},{diff} msec, TIME DISCREPANCY IN DATA')
    else:
        print(f'trial{index} pass')
# Out:
# trial0,2532581 msec, TIME DISCREPANCY IN DATA
# trial1 pass
# trial2 pass
# trial3 pass
# trial4 pass
# trial5 pass
# trial6 pass
# trial7 pass
# trial8 pass
# trial9 pass

# %% [markdown]
# ### EDA

# %% [markdown]
# #### wrt svc_event

# %% [markdown]
# ##### interpolate sensor data

# %%
def convert_time(row):
    '''convert msec to min'''
    minutes, seconds = divmod(row['t'] / 1000, 60)
    row['t_min'] = f'{minutes:0>2.0f}'  # only in min
    return row

# %% [markdown]
# **merge main**

# %%
list_of_mains = []

for tsd, df in zip(list_of_tsds,list_of_dfs):
    # check duplicates
    ids = df['time_msec']
    df[ids.isin(ids[ids.duplicated()])]
    
    # drop duplicates
    df = df.drop_duplicates(subset=['time_msec'],keep='first')
    
    df = df.set_index('time_msec')
    df = df.reindex(range(0,df.index.astype(int)[-1]+1), fill_value=np.nan)
    df = df.reset_index()
    df.drop(labels=0,axis=0,inplace=True)
    
    # interpolate missing data
    df['rawdatax'] = df['rawdatax'].interpolate().values.ravel().tolist()
    df['rawdatay'] = df['rawdatay'].interpolate().values.ravel().tolist()
    
    # merge main df
    main = pd.merge(tsd, df, how='left', left_on='t', right_on='time_msec')
    main = main.apply(convert_time, axis=1)
    main['t_min'] = main['t_min'].astype(int)
    list_of_mains.append(main)

# %%
list_of_mains[0]
# Out:
#           t           event_type  obstacles_outcome  time_msec  rawdatax  \
# 0       289  service_event_start                  0        289  0.170601
# 1       639            retrieval                  0        639  0.170601
# 2       639            collision                  1        639  0.170601
# 3       680            collision                  1        680  0.170601
# 4       712         outcome_type                  1        712  0.170601
# ..      ...                  ...                ...        ...       ...
# 591  279874            retrieval                  0     279874  0.215765
# 592  280716            collision                  1     280716  0.213849
# 593  281218         outcome_type                  1     281218  0.211502
# 594  281721    service_event_end                  1     281721  0.210607
# 595  282224  service_event_start                  0     282224  0.209984
#
#      rawdatay  rawdatatorqueleft  rawdatatorqueright  t_min
# 0    0.059062                NaN                 NaN      0
# 1    0.059062                NaN                 NaN      0
# 2    0.059062                NaN                 NaN      0
# 3    0.059062                0.0                 0.0      0
# 4    0.059062                NaN                 NaN      0
# ..        ...                ...                 ...    ...
# 591  0.198574                NaN                 NaN      4
# 592  0.207466                NaN                 NaN      4
# 593  0.223626                NaN                 NaN      4
# 594  0.236052                NaN                 NaN      4
# 595  0.237077                NaN                 NaN      4
#
# [596 rows x 9 columns]

# %%
## double check NaN beginning and end of df

# %% [markdown]
# ##### mean speed

# %%
# mean speed
list_svc = []
mean_speed = []
list_of_tot_svc = []

for idx, main in enumerate(list_of_mains):
    svc_event = main[main['event_type'].str.contains('service_event')]

    # index pairs of service_event start/end
    nr = 0
    svc_event['sequence'] = 0
    for index, event in enumerate(svc_event['event_type']):
        if event == 'service_event_start':
            svc_event['sequence'].iloc[index] = nr
        else:
            svc_event['sequence'].iloc[index] = nr
            nr += 1  
    
    # group events based on svc_events
    svc_event[['time_diff','x_diff','y_diff']]=svc_event.groupby('sequence')[['time_msec','rawdatax','rawdatay']].diff()
    svc_event['step_size'] = np.sqrt(svc_event['x_diff']**2+svc_event['y_diff']**2)
    svc_event['speed'] = (svc_event['step_size'])/(svc_event['time_diff']/1000)
    svc_event.drop(columns=['rawdatatorqueleft','rawdatatorqueright'],inplace=True)
    svc_event = svc_event.dropna()
    list_svc.append(svc_event)
    
    # total number of customers served
    list_of_tot_svc.append(int(list_of_reps[idx]['value'][6]))

    mean_speed.append(statistics.mean(svc_event['speed']))

# %%
# sample of one df
list_svc[0]
# Out:
#           t         event_type  obstacles_outcome  time_msec  rawdatax  \
# 5       746  service_event_end                  1        746  0.170601
# 9      1934  service_event_end                  1       1934  0.170601
# 22     8129  service_event_end                  2       8129  0.167811
# 27    11110  service_event_end                  1      11110  0.167434
# 33    15650  service_event_end                  3      15650  0.156175
# 36    18062  service_event_end                  1      18062  0.178086
# 41    21341  service_event_end                  1      21341  0.251533
# 50    24783  service_event_end                  1      24783  0.298682
# 56    28243  service_event_end                  1      28243  0.331124
# 61    30621  service_event_end                  1      30621  0.325514
# 68    33623  service_event_end                  1      33623  0.295496
# 73    35683  service_event_end                  1      35683  0.294028
# 81    41029  service_event_end                  1      41029  0.297079
# 85    42589  service_event_end                  1      42589  0.308700
# 91    44892  service_event_end                  1      44892  0.330118
# 97    46153  service_event_end                  1      46153  0.315537
# 102   48390  service_event_end                  1      48390  0.316044
# 108   50452  service_event_end                  1      50452  0.313496
# 114   52616  service_event_end                  1      52616  0.308982
# 120   55815  service_event_end                  1      55815  0.305036
# 125   56634  service_event_end                  1      56634  0.295697
# 131   59432  service_event_end                  1      59432  0.222480
# 139   64218  service_event_end                  1      64218  0.092835
# 143   66137  service_event_end                  1      66137  0.077761
# 148   68515  service_event_end                  1      68515  0.072910
# 154   70653  service_event_end                  1      70653  0.073161
# 161   74554  service_event_end                  1      74554  0.117310
# 167   78679  service_event_end                  1      78679  0.145262
# 172   81220  service_event_end                  1      81220  0.150244
# 179   83144  service_event_end                  3      83144  0.158050
# 182   84011  service_event_end                  1      84011  0.174497
# 189   87256  service_event_end                  1      87256  0.157029
# 193   88957  service_event_end                  1      88957  0.156175
# 199   91197  service_event_end                  1      91197  0.144744
# 205   93862  service_event_end                  1      93862  0.138079
# 209   96423  service_event_end                  1      96423  0.133857
# 215   99325  service_event_end                  1      99325  0.133932
# 221  101907  service_event_end                  1     101907  0.134184
# 231  106580  service_event_end                  1     106580  0.149892
# 239  111403  service_event_end                  1     111403  0.150445
# 248  116336  service_event_end                  3     116336  0.164273
# 251  118422  service_event_end                  1     118422  0.206722
# 257  121319  service_event_end                  1     121319  0.258767
# 262  122717  service_event_end                  1     122717  0.272539
# 270  126801  service_event_end                  1     126801  0.220550
# 285  134770  service_event_end                  1     134770  0.193070
# 291  138130  service_event_end                  1     138130  0.150746
# 300  142475  service_event_end                  1     142475  0.142427
# 308  144657  service_event_end                  3     144657  0.151033
# 311  145213  service_event_end                  3     145213  0.152767
# 314  147000  service_event_end                  1     147000  0.152706
# 319  150198  service_event_end                  1     150198  0.150068
# 324  153377  service_event_end                  1     153377  0.142251
# 330  156559  service_event_end                  2     156559  0.145644
# 334  159240  service_event_end                  1     159240  0.145971
# 340  163404  service_event_end                  1     163404  0.142925
# 346  164965  service_event_end                  1     164965  0.145971
# 352  166642  service_event_end                  1     166642  0.144413
# 358  168581  service_event_end                  1     168581  0.143784
# 366  170222  service_event_end                  1     170222  0.147906
# 379  177528  service_event_end                  1     177528  0.190029
# 385  181109  service_event_end                  1     181109  0.136692
# 394  184490  service_event_end                  1     184490  0.075750
# 401  189314  service_event_end                  1     189314  0.074217
# 412  195423  service_event_end                  1     195423  0.086959
# 419  198405  service_event_end                  1     198405  0.078967
# 426  201846  service_event_end                  3     201846  0.087331
# 429  203352  service_event_end                  1     203352  0.089799
# 434  206449  service_event_end                  1     206449  0.089523
# 439  208446  service_event_end                  1     208446  0.085527
# 449  212253  service_event_end                  1     212253  0.097414
# 456  215555  service_event_end                  3     215555  0.083064
# 459  216683  service_event_end                  1     216683  0.074790
# 466  221243  service_event_end                  1     221243  0.078017
# 472  225720  service_event_end                  1     225720  0.098269
# 478  228859  service_event_end                  1     228859  0.098370
# 484  231063  service_event_end                  1     231063  0.066034
# 488  232097  service_event_end                  1     232097  0.060092
# 492  234452  service_event_end                  1     234452  0.054312
# 500  239276  service_event_end                  1     239276  0.047250
# 507  242080  service_event_end                  3     242080  0.040941
# 510  243245  service_event_end                  1     243245  0.048632
# 519  246290  service_event_end                  3     246290  0.124709
# 522  247338  service_event_end                  1     247338  0.166942
# 528  250361  service_event_end                  1     250361  0.202545
# 533  253258  service_event_end                  1     253258  0.202570
# 539  256759  service_event_end                  1     256759  0.190245
# 548  259966  service_event_end                  1     259966  0.187676
# 556  263826  service_event_end                  3     263826  0.162106
# 559  265612  service_event_end                  1     265612  0.162106
# 568  270318  service_event_end                  1     270318  0.280662
# 578  275552  service_event_end                  1     275552  0.285960
# 586  278358  service_event_end                  1     278358  0.235680
# 594  281721  service_event_end                  1     281721  0.210607
#
#      rawdatay  t_min  sequence  time_diff    x_diff    y_diff  step_size  \
# 568  0.194749      4        90     4143.0  0.118129 -0.005434   0.118254
# 578  0.183439      4        91     4869.0  0.004549 -0.004549   0.006433
# 586  0.195869      4        92     2160.0 -0.049351  0.004152   0.049525
# 594  0.236052      4        93     3161.0 -0.021770  0.039966   0.045511
#
#         speed
# 5    0.000000
# 9    0.000000
# 22   0.024458
# 27   0.000206
# 33   0.003029
# 36   0.013618
# 41   0.022445
# 50   0.010615
# 56   0.013335
# 61   0.029903
# 68   0.017980
# 73   0.005620
# 81   0.007174
# 85   0.019986
# 91   0.013151
# 97   0.011680
# 102  0.008813
# 108  0.011417
# 114  0.013157
# 120  0.002479
# 125  0.019801
# 131  0.025876
# 139  0.026443
# 143  0.021570
# 148  0.004075
# 154  0.000984
# 161  0.011510
# 167  0.007785
# 172  0.000500
# 179  0.006742
# 182  0.008882
# 189  0.005941
# 193  0.000707
# 199  0.005209
# 205  0.009918
# 209  0.003664
# 215  0.000247
# 221  0.000110
# 231  0.004496
# 239  0.003761
# 248  0.008586
# 251  0.021683
# 257  0.020201
# 262  0.010020
# 270  0.015483
# 285  0.002690
# 291  0.016227
# 300  0.010932
# 308  0.008579
# 311  0.013741
# 314  0.000191
# 319  0.003601
# 324  0.003098
# 330  0.002723
# 334  0.006791
# 340  0.003875
# 346  0.005690
# 352  0.009667
# 358  0.011280
# 366  0.006381
# 379  0.006057
# 385  0.020344
# 394  0.018917
# 401  0.007119
# 412  0.005558
# 419  0.004874
# 426  0.004161
# 429  0.018311
# 434  0.000098
# 439  0.004005
# 449  0.003308
# 456  0.005238
# 459  0.011860
# 466  0.004350
# 472  0.009095
# 478  0.015101
# 484  0.016907
# 488  0.009654
# 492  0.008770
# 500  0.002177
# 507  0.003985
# 510  0.027967
# 519  0.028737
# 522  0.040482
# 528  0.007964
# 533  0.000014
# 539  0.004253
# 548  0.004941
# 556  0.007825
# 559  0.000000
# 568  0.028543
# 578  0.001321
# 586  0.022928
# 594  0.014398

# %%
## quality check 
# no end for the last service_event_
list_of_tsds[0][list_of_tsds[0]['event_type'].str.contains('service')].tail(5)
# Out:
#           t           event_type  obstacles_outcome
# 579  276198  service_event_start                  0
# 586  278358    service_event_end                  1
# 587  278560  service_event_start                  0
# 594  281721    service_event_end                  1
# 595  282224  service_event_start                  0

# %%
# result mean_speed of all trials
mean_speed
# Out:
# [0.010084993232424984,
#  0.01627325239561165,
#  0.01119446779826725,
#  0.011022403285336031,
#  0.013170289266475859,
#  0.01489688186148147,
#  0.017274835726848143,
#  0.018475100733308016,
#  0.01813766679195982,
#  0.01634152548311976]

# %%
# plot speed and mean_speed based on svc_event
for index, svc_event in enumerate(list_svc):
    fig, ax = plt.subplots()

    ax.plot('sequence','speed',data=svc_event);
    ax.axhline(y=mean_speed[index], color='r', linestyle='-')
    
    plt.legend(['speed','mean_speed'])
    plt.xlabel('service event')
    plt.ylabel('speed/ m/msec')
    plt.title('speed during play');

# %% [markdown]
# **how does the system determine a correction/rectification made?**

# %% [markdown]
# ##### service event errors rate

# %% [markdown]
#  1 (Correct item & correct person in sequence)
#  <br> 2 (Correct item & wrong person in sequence)
#  <br> 3 (Wrong item & wrong person in sequence).

# %%
# error rate
error_rate = []

for index, (main, svc_event) in enumerate(zip(list_of_mains,list_svc)):
    svc_error = main[main['event_type']=='service_event_end']['obstacles_outcome'].unique()
    
#     svc_event.reset_index(inplace=True)
    total_svc = int(svc_event['sequence'].tail(1))
    if 2 in svc_error:
        svc_error_2 = svc_event[svc_event['obstacles_outcome']==2]['obstacles_outcome'].count()
    else:
        svc_error_2 = 0
    if 3 in svc_error:
        svc_error_3 = svc_event[svc_event['obstacles_outcome']==3]['obstacles_outcome'].count()
    else:
        svc_error_3 = 0
        
    error_rate.append((svc_error_2 + svc_error_3)/list_of_tot_svc[index])

# %%
# result error_rate based on svc_event
error_rate
# Out:
# [0.14285714285714285,
#  0.027777777777777776,
#  0.1111111111111111,
#  0.027777777777777776,
#  0.034482758620689655,
#  0.06944444444444445,
#  0.041666666666666664,
#  0.05555555555555555,
#  0.0763888888888889,
#  0.05555555555555555]

# %% [markdown]
# ##### collision rate

# %% [markdown]
# collisions=1 if shelf
# <br> collisions=2 if object

# %%
# collision rate
collision_rate = []

for index, main in enumerate(list_of_mains):
    coll_1 = main[(main['event_type']=='collision') & (main['obstacles_outcome']==1)]['obstacles_outcome'].count()
    coll_2 = main[(main['event_type']=='collision') & (main['obstacles_outcome']==2)]['obstacles_outcome'].count()
    collision_rate.append((coll_1 + coll_2)/list_of_tot_svc[index])

# %%
collision_rate
# Out:
# [2.6785714285714284,
#  0.3194444444444444,
#  1.8263888888888888,
#  0.8125,
#  0.6344827586206897,
#  0.5416666666666666,
#  0.4236111111111111,
#  0.4236111111111111,
#  0.2777777777777778,
#  0.2569444444444444]

# %% [markdown]
# #### rolling

# %% [markdown]
# ##### mean speed (rolling)

# %%
# define window of interest
# this applies to all parameters
window = int(input("window: "))
# Out:
# window: 7

# %%
list_speed_roll = []

for index, svc_event in enumerate(list_svc):
    svc_event.set_index('sequence')
    svc_event['speed_roll']=svc_event['speed'].rolling(window).mean()
    list_speed_roll.append(svc_event['speed_roll'])
    
    #plot moving average based on window
    fig, ax = plt.subplots()
    ax.plot('sequence','speed_roll',data=svc_event);
    plt.xlabel('svc_event')
    plt.ylabel('speed/ m/msec')
    plt.title(f'moving average ({window} svc events) of speed during play');

# %% [markdown]
# ##### svc event errors rate (rolling)

# %%
list_error_rate = []

for index, svc_event in enumerate(list_svc):
    svc_event['error_rate'] = np.nan
    
    for i in range(0,(len(svc_event)-window+1)):
        svc_error = svc_event[svc_event['event_type']=='service_event_end']['obstacles_outcome'][i:i+window].unique()
        if 2 in svc_error:
            svc_error_2 = svc_event[i:i+window][svc_event['obstacles_outcome']==2]['obstacles_outcome'].count()
        else:
            svc_error_2 = 0
        if 3 in svc_error:
            svc_error_3 = svc_event[i:i+window][svc_event['obstacles_outcome']==3]['obstacles_outcome'].count()
        else:
            svc_error_3 = 0
        svc_event['error_rate'][i+window] = (svc_error_2 + svc_error_3)/window
        list_error_rate.append((svc_error_2 + svc_error_3)/window)
    
    #plot moving average based on window
    fig, ax = plt.subplots()
    ax.plot('error_rate',data=svc_event);
    plt.xlabel('service event')
    plt.ylabel('error rate')
    plt.title(f'moving average ({window} svc events) of error rate during play');

# %% [markdown]
# ##### total collision (svc, rolling)

# %%
list_tot_coll = []

for main in list_of_mains:
    collision = main[main['event_type'].str.contains('collision|service')]
    
    # index pairs of service_event start/end
    nr = 0
    collision['sequence'] = 0
    for index, event in enumerate(collision['event_type']):
        if event == 'service_event_start':
            collision['sequence'].iloc[index] = nr
        elif event == 'collision':
            collision['sequence'].iloc[index] = nr
        elif event == 'service_event_end':
            collision['sequence'].iloc[index] = nr
            nr += 1 
            
    # collision 1
    coll_1 = collision[(collision['event_type']=='collision') & (collision['obstacles_outcome']==1)].groupby('sequence').count()[['obstacles_outcome']]
    coll_1 = coll_1.rename(columns={'obstacles_outcome':'coll_1'})

    # collision 2
    coll_2 = collision[(collision['event_type']=='collision') & (collision['obstacles_outcome']==2)].groupby('sequence').count()[['obstacles_outcome']]
    coll_2 = coll_2.rename(columns={'obstacles_outcome':'coll_2'})

    # total collisions
    total_coll = pd.merge(coll_1, coll_2, how='left', on='sequence').replace(np.nan,0)
    total_coll = total_coll.reindex(range(0,total_coll.index.astype(int)[-1]+1), fill_value=0)
    total_coll['total_coll'] = total_coll['coll_1'] + total_coll['coll_2']
    
    #
    fig, ax1 = plt.subplots()
    ax1.plot('total_coll',data=total_coll);
    plt.xlabel('service event')
    plt.ylabel('total collision')
    plt.title('total collision during play'); 
    
    # total collision (rolling)
    total_coll['total_coll7']=total_coll['total_coll'].rolling(window).mean()
    list_tot_coll.append(total_coll['total_coll7'])
    
    #plot moving average based on window
    fig, ax2 = plt.subplots()
    ax2.plot('total_coll7',data=total_coll);
    plt.xlabel('service event')
    plt.ylabel('collision rate')
    plt.title(f'moving average ({window} svc events) of total collision during play');

# %% [markdown]
# ### plot summary of all trials

# %%
progress = pd.DataFrame({'mean_speed': mean_speed, 
                        'error_rate': error_rate, 
                        'collision_rate': collision_rate})

# %%
progress
# Out:
#    mean_speed  error_rate  collision_rate
# 0    0.010085    0.142857        2.678571
# 1    0.016273    0.027778        0.319444
# 2    0.011194    0.111111        1.826389
# 3    0.011022    0.027778        0.812500
# 4    0.013170    0.034483        0.634483
# 5    0.014897    0.069444        0.541667
# 6    0.017275    0.041667        0.423611
# 7    0.018475    0.055556        0.423611
# 8    0.018138    0.076389        0.277778
# 9    0.016342    0.055556        0.256944

# %%
# plot mean_speed of all trials
plt.bar(progress.index,height=progress['mean_speed']);
plt.xlabel('trial')
plt.ylabel('mean speed');
plt.title('mean speed by trial');

# %%
# plot error_rate of all trials
plt.bar(progress.index,height=progress['error_rate']);
plt.xlabel('trial')
plt.ylabel('error rate');
plt.title('service error rate by trial');

# %%
# plot collisions of all trials
plt.bar(progress.index,height=progress['collision_rate']);
plt.xlabel('trial')
plt.ylabel('collision rate');
plt.title('collision rate by trial');
